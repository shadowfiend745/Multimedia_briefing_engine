# %%
import anthropic
from pypdf import PdfReader

# %%
filePath = "C:/Github/Multimedia_briefing_engine/Arknights_Endfield_Wikipedia.pdf"
reader = PdfReader(filePath)
rawText = " ".join("".join(page.extract_text() for page in reader.pages).split())
print(rawText[:500])  # Print the first 500 characters of the extracted text
# Out:
# Arknights: Endfield Developers Hypergryph Mountain Contour Publishers CHN: Hypergryph TWN/HKG/MAC: Ariel WW: Gryphline Series Arknights Engine Unity[1] Platforms Android iOS PlayStation 5 Windows Release 22 January 2026 Genre Action-adventure Modes Single-player, multiplayer Arknights: Endfield A screenshot of combat in Endfield. Arknights: Endfield Arknights: Endfield[a] is an action role-playing game developed and published by Hypergryph. It is a spinoff of Hypergryph's 2019 tower defense game

# %%
client = anthropic.Anthropic()

message = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=1024,
    system="""You are a content briefing assistant.
When given a piece of text, extract and structure the key ideas into:
- INTRO: One sentence explaining what this content is about
- KEY POINTS: 5 to 7 bullet points, each being one clear idea
- SUMMARY: Two sentences wrapping up the main takeaway

Reply in plain text using exactly those section headers.""",
    messages=[
        {
            "role": "user",
            "content": f"please extract the key ideas from the following text:\n\n{rawText}"
        }
    ]
)

briefing = message.content[0].text
print(briefing)
# Out:
# INTRO
# Arknights: Endfield is a real-time 3D action role-playing game developed by Hypergryph that launched on January 22, 2026, combining combat, exploration, and factory-building mechanics in a sci-fi setting on the moon Talos-II.
#
# KEY POINTS
# • The game features a combo-based combat system where players control a four-member team simultaneously, switching between characters to use tactical skills, combo abilities, and ultimate attacks while managing shared skill gauges and enemy imbalance mechanics.
#
# • A base-building and industrial management system inspired by games like Factorio allows players to harvest resources, process materials via conveyor belts, and manage electricity distribution, with developers aiming for a 50:50 balance between RPG and factory elements.
#
# • The story takes place on the moon Talos-II, colonized 152 years prior by Terran pioneers who became stranded after a dimensional portal closed, with the player as "Endministrator" of Endfield Industries exploring ruins and battling creatures called Aggeloi and armed raiders.
#
# • Critical reception was mostly positive with Metacritic scoring 78/100 and 88% positive reviews on OpenCritic, with praise for visuals, music, character design, and the unique blend of action RPG with factory mechanics.
#
# • Reviewers noted both strengths and weaknesses, with some praising the compelling combat and atmosphere while others criticized repetitive gameplay, grinding requirements, narrative pacing, and the complexity of multiple game systems.
#
# • The game launched successfully with over 35 million pre-registrations worldwide, ranked 2nd on iOS App Store charts on day one, and over 1 million downloads on Google Play Store, though it experienced a PayPal payment glitch that was quickly resolved.
#
# • The game is available across multiple platforms including PC, PlayStation 5, iOS, and Android, with cross-platform progression support.
#
# SUMMARY
# Arknights: Endfield successfully blends action combat, exploration, and factory-building into a cohesive gacha game that received mostly positive reviews for its visual presentation and mechanical innovation, though criticisms about repetitive gameplay and grinding tempered some enthusiasm. The game's strong launch metrics and critical reception suggest it has found an audience despite the crowded gacha game market.

# %%
with open("briefing.txt", "w") as f:    
    f.write(briefing)
